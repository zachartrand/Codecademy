# %% [markdown]
# # [DATA WRANGLING AND TIDYING](https://www.codecademy.com/paths/data-science/tracks/dscp-data-wrangling-and-tidying/modules/dscp-data-cleaning-with-pandas/projects/data-cleaning-us-census)
#
# ## Cleaning US Census Data
#
# You just got hired as a Data Analyst at the Census Bureau, which collects census data and creates interesting visualizations and insights from it.
#
# The person who had your job before you left you all the data they had for the most recent census. It is in multiple `csv` files. They didn’t use pandas, they would just look through these `csv` files manually whenever they wanted to find something. Sometimes they would copy and paste certain numbers into Excel to make charts.
#
# The thought of it makes you shiver. This is not scalable or repeatable.
#
# Your boss wants you to make some scatterplots and histograms by the end of the day. Can you get this data into `pandas` and into reasonable shape so that you can make these histograms?

# %% [markdown]
# ### Inspect the Data!
#
# 1. The first visualization your boss wants you to make is a scatterplot that shows average income in a state vs proportion of women in that state.
#
#     Open some of the census `csv` files in the navigator (click the file icon in the top left corner of the code editor and then click on any of the `csv` files to open them). How are they named? What kind of information do they hold? Will they help us make this graph?

# %% [markdown]
# 2. It will be easier to inspect this data once we have it in a DataFrame. You can’t even call `.head()` on these `csv`s! How are you supposed to read them?
#
#     Using `glob`, loop through the census files available and load them into DataFrames. Then, concatenate all of those DataFrames together into one DataFrame, called something like `us_census`.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import glob

# %%
files = glob.glob("states*.csv")
df_list = []
for file in files:
    df_list.append(pd.read_csv(file))

us_census = pd.concat(df_list)
us_census = us_census[us_census.columns[1:]]

# %% [markdown]
# 3. Look at the `.columns` and the `.dtypes` of the `us_census` DataFrame. Are those datatypes going to hinder you as you try to make histograms?

# %%
print(us_census.columns)
print(us_census.dtypes)
# Out:
# Index(['State', 'TotalPop', 'Hispanic', 'White', 'Black', 'Native', 'Asian',
#        'Pacific', 'Income', 'GenderPop'],
#       dtype='object')
# State        object
# TotalPop      int64
# Hispanic     object
# White        object
# Black        object
# Native       object
# Asian        object
# Pacific      object
# Income       object
# GenderPop    object
# dtype: object

# %% [markdown]
# 3. Answer: Yes, all of the numbers I want to work with, except the ones in the TotalPop column, are objects instead of ints or floats.

# %% [markdown]
# 4. Look at the .head() of the DataFrame so that you can understand why some of these dtypes are objects instead of integers or floats.
#
#     Start to make a plan for how to convert these columns into the right types for manipulation.

# %%
us_census.head()
# Out:
#         State  TotalPop             Hispanic                White  \
# 0     Alabama   4830620  3.7516156462584975%     61.878656462585%
# 1      Alaska    733375   5.909580838323351%  60.910179640718574%
# 2     Arizona   6641928  29.565921052631502%  57.120000000000026%
# 3    Arkansas   2958208   6.215474452554738%   71.13781021897813%
# 4  California  38421464  37.291874687968054%   40.21578881677474%
#
#                  Black                Native                Asian  \
# 0   31.25297619047618%   0.4532312925170065%  1.0502551020408146%
# 1  2.8485029940119775%    16.39101796407186%   5.450299401197604%
# 2  3.8509868421052658%     4.35506578947368%   2.876578947368419%
# 3  18.968759124087573%   0.5229197080291965%  1.1423357664233578%
# 4   5.677396405391911%  0.40529206190713685%  13.052234148776776%
#
#                 Pacific              Income            GenderPop
# 0  0.03435374149659865%  $43296.35860306644    2341093M_2489527F
# ...

# %% [markdown]
# ### Regex to the Rescue
#
# 5. Use regex to turn the `Income` column into a format that is ready for conversion into a numerical type.

# %%
us_census.Income = us_census["Income"].replace("[\$,]", "", regex=True)
us_census.Income = pd.to_numeric(us_census.Income)

us_census.TotalPop = pd.to_numeric(us_census.TotalPop, downcast="unsigned")

# %% [markdown]
# 6. Look at the GenderPop column. We are going to want to separate this into two columns, the Men column, and the Women column.
# gender_pop = us_census.GenderPop.str.split("_")
#     Split the column into those two new columns using str.split and separating out those results.

# %%
gender_pop = us_census.GenderPop.str.split("_")

# %% [markdown]
# 7. Convert both of the columns into numerical datatypes.
#
#     There is still an M or an F character in each entry! We should remove those before we convert.

# %%
us_census["Men"] = gender_pop.str.get(0)
us_census["Women"] = gender_pop.str.get(1)
us_census.Men = us_census.Men.str.replace("M", "")
us_census.Women = us_census.Women.str.replace("F", "")
us_census.Men = pd.to_numeric(us_census.Men, downcast="unsigned")
us_census.Women = pd.to_numeric(us_census.Women)

# %% [markdown]
# 8. Now you should have the columns you need to make the graph and make sure your boss does not slam a ruler angrily on your desk because you’ve wasted your whole day cleaning your data with no results to show!
#
#     Use matplotlib to make a scatterplot!
#
#     ```python
#     plt.scatter(the_women_column, the_income_column)
#     ```
#
#
#     Remember to call `plt.show()` to see the graph!

# %%
plt.subplot()
plt.scatter(us_census.Women, us_census.Income)
plt.show()

# %% [markdown]
# 9. You want to double check your work. You know from experience that these monstrous csv files probably have `nan` values in them! Print out your column with the number of women per state to see.

# %%
print(us_census.Women)
# Out:
# 0     2489527.0
# 1      349215.0
# 2     3342840.0
# 3     1506295.0
# 4    19334329.0
# 5     2630239.0
# 0     2630239.0
# 1     1841615.0
# 2      478041.0
# 3      340810.0
# 4    10045763.0
# 5     5123362.0
# 0     5123362.0
# 1      696428.0
# 2      806083.0
# 3     6556862.0
# 4     3333382.0
# 5     1558931.0
# 0     1558931.0
# 1     1453125.0
# 2     2233145.0
# 3     2364097.0
# 4      679019.0
# 5           NaN
# 0           NaN
# 1     3455936.0
# 2     5038598.0
# 3     2727005.0
# 4     1536358.0
# 5     3081445.0
# 0     3081445.0
# 1           NaN
# 2      939759.0
# 3     1390901.0
# 4      670717.0
# 5     4561386.0
# 0     4561386.0
# 1     1051703.0
# 2    10131373.0
# 3     5049925.0
# 4      353677.0
# 5     5913084.0
# 0     5913084.0
# 1     1942789.0
# 2     1990780.0
# 3     6534215.0
# 4     1869213.0
# 5      543273.0
# 0      543273.0
# 1     2455167.0
# 2      419713.0
# 3     3331859.0
# 4    13367298.0
# 5     1444150.0
# 0     1444150.0
# ...

# %% [markdown]
# 9. *(continued)* We can fill in those `nan`s by using pandas’ `.fillna()` function.
#
#     You have the `TotalPop` per state, and you have the `Men` per state. As an estimate for the `nan` values in the `Women` column, you could use the `TotalPop` of that state minus the `Men` for that state.
#
#     Print out the `Women` column after filling the `nan` values to see if it worked!

# %%
us_census.Women = us_census.Women.fillna(us_census.TotalPop - us_census.Men)
us_census.Women = pd.to_numeric(us_census.Women, downcast="unsigned")
print(us_census.Women.dtype)
# Out:
# uint32

# %% [markdown]
# 10. We forgot to check for duplicates! Use `.duplicated()` on your `census` DataFrame to see if we have duplicate rows in there.

# %%
us_census[us_census.duplicated()]
# Out:
#           State  TotalPop             Hispanic                White  \
# 0      Colorado   5278906   20.78438003220608%   69.89557165861504%
# 0       Georgia  10006693   8.418242207460397%   54.28630556974962%
# 0          Iowa   3093526    5.30364520048603%   87.71968408262464%
# 0      Maryland   5930538    8.47249820014399%     52.679049676026%
# 0      Missouri   6045448   4.037247838616718%     77.508069164265%
# 0    New Jersey   8904413   18.74950049950049%  56.488761238761285%
# 0          Ohio  11575977  3.6720843250595037%   75.90306018361096%
# 0  Rhode Island   1053661  13.356666666666678%   74.32541666666665%
# 0          Utah   2903379  13.468376068376063%   79.40683760683764%
#
#                  Black                Native                Asian  \
# 0   3.546376811594201%   0.5738325281803548%   2.661996779388082%
# 0   32.08829841594277%  0.18758303525804798%  3.0976494634644895%
# 0  3.2569866342648868%   0.2897934386391251%   1.699392466585662%
# ...

# %% [markdown]
# 11. Drop those duplicates using the `.drop_duplicates()` function.

# %%
us_census = us_census.drop_duplicates()

# %% [markdown]
# 12. Make the scatterplot again. Now, it should be perfect! Your job is secure, for now.

# %%
plt.subplot()
plt.scatter(us_census.Women, us_census.Income)
plt.xlabel("State female population")
plt.ylabel("State average income")
plt.show()

# %% [markdown]
# ### Histograms of Races
#
# 13. Now, your boss wants you to make a bunch of histograms out of the race data that you have. Look at the `.columns` again to see what the race categories are.

# %%
print(us_census.columns)
# Out:
# Index(['State', 'TotalPop', 'Hispanic', 'White', 'Black', 'Native', 'Asian',
#        'Pacific', 'Income', 'GenderPop', 'Men', 'Women'],
#       dtype='object')

# %% [markdown]
# 14. Try to make a histogram for each one!
#
#     You will have to get the columns into numerical format, and those percentage signs will have to go.
#
#     Don’t forget to fill the nan values with something that makes sense! You probably dropped the duplicate rows when making your last graph, but it couldn’t hurt to check for duplicates again.

# %%
demographics = us_census.columns[2:8]

# %%
for column in demographics:
    us_census[column] = us_census[column].replace("[%,]", "", regex=True)
    us_census[column] = pd.to_numeric(us_census[column], downcast="float")
    print(us_census[column][us_census[column].isna()])
# Out:
# Series([], Name: Hispanic, dtype: float32)
# Series([], Name: White, dtype: float32)
# Series([], Name: Black, dtype: float32)
# Series([], Name: Native, dtype: float32)
# Series([], Name: Asian, dtype: float32)
# 5   NaN
# 2   NaN
# 1   NaN
# 4   NaN
# Name: Pacific, dtype: float32

# %%
us_census.Pacific = us_census.Pacific.fillna(
    100.0 - us_census.Black 
    - us_census.Native 
    - us_census.Asian 
    - us_census.White 
    - us_census.Hispanic)

# %%
number_of_graphs = len(demographics)
for i, column in enumerate(demographics):
    ax = plt.subplot()
    plt.hist(us_census[column])
    plt.title(f"{column}")
    plt.xlabel(f"% of the poputation who are {column}")
    plt.ylabel(f"# of states")
    plt.xlim(0, 100)
    ax.set_aspect('auto', 'box')
    
    plt.show()

# %% [markdown]
# ### Get Creative
#
# 15. Phew. You’ve definitely impressed your boss on your first day of work.
#
#     But is there a way you really convey the power of pandas and Python over the drudgery of csv and Excel?
#
#     Try to make some more interesting graphs to show your boss, and the world! You may need to clean the data even more to do it, or the cleaning you have already done may give you the ease of manipulation you’ve been searching for

# %%
us_census = us_census.reset_index()
us_census = us_census.drop(columns=["index", "GenderPop"])

# %%
us_census.State = us_census.State.convert_dtypes()

# %%
print(us_census.dtypes)
# Out:
# State        string
# TotalPop     uint32
# Hispanic    float32
# White       float32
# Black       float32
# Native      float32
# Asian       float32
# Pacific     float32
# Income      float64
# Men          uint32
# Women        uint32
# dtype: object

# %%
us_census
# Out:
#                    State  TotalPop   Hispanic      White      Black  \
# 0                Alabama   4830620   3.751616  61.878658  31.252975
# 1                 Alaska    733375   5.909581  60.910179   2.848503
# 2                Arizona   6641928  29.565922  57.119999   3.850987
# 3               Arkansas   2958208   6.215475  71.137810  18.968760
# 4             California  38421464  37.291874  40.215790   5.677396
# 5               Colorado   5278906  20.784380  69.895569   3.546377
# 6            Connecticut   3593222  15.604831  67.677055  10.348067
# 7               Delaware    926454   8.824766  64.632713  20.743925
# 8   District of Columbia    647484   9.165922  33.103912  51.776535
# 9                Florida  19645772  21.338543  59.083748  15.165676
# 10               Georgia  10006693   8.418242  54.286304  32.088299
# 11                Hawaii   1406299   9.186708  25.032278   2.052848
# 12                 Idaho   1616547  11.505369  83.136238   0.566779
# ...
